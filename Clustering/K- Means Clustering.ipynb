# %% [markdown]
# # K- Means Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers=3,cluster_std=1.8,random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=6)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=6, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-9.71497727, -5.1548456 ],
#        [ 1.70987954,  6.38524046],
#        [ 5.3403152 ,  7.17746837],
#        [-1.40167654,  2.14661958],
#        [ 1.72394661,  1.0638259 ],
#        [-9.12655238, -8.50143223]])

# %%
kmeans.labels_
# Out:
# array([4, 0, 4, 3, 5, 3, 2, 3, 5, 4, 1, 4, 4, 2, 2, 4, 0, 4, 0, 0, 2, 5,
#        0, 1, 0, 4, 3, 0, 0, 1, 3, 3, 3, 0, 0, 2, 1, 1, 5, 2, 5, 0, 4, 5,
#        1, 3, 4, 2, 4, 1, 0, 3, 0, 2, 4, 3, 1, 2, 4, 0, 5, 0, 5, 5, 4, 5,
#        1, 5, 0, 0, 1, 0, 1, 4, 2, 0, 2, 1, 3, 4, 5, 0, 5, 4, 4, 1, 5, 3,
#        4, 4, 0, 2, 4, 0, 1, 2, 2, 2, 4, 4, 4, 3, 1, 4, 5, 2, 0, 0, 1, 2,
#        1, 0, 5, 1, 1, 2, 2, 3, 2, 1, 0, 1, 0, 4, 1, 4, 1, 2, 2, 1, 3, 0,
#        5, 1, 5, 1, 0, 3, 0, 0, 0, 1, 2, 5, 4, 1, 2, 1, 1, 2, 3, 3, 3, 2,
#        0, 5, 0, 3, 5, 4, 4, 1, 4, 2, 3, 1, 2, 3, 1, 4, 2, 1, 3, 1, 5, 2,
#        5, 0, 2, 4, 4, 4, 3, 5, 1, 5, 0, 3, 5, 0, 2, 2, 5, 3, 0, 0, 0, 3,
#        3, 3], dtype=int32)

# %%
f, (ax1,ax2) = plt.subplots(1,2,sharey=True,figsize= (12,7))
ax1.set_title('K-Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
